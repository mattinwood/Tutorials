# %%
# Import packages for plotting and sample data
import matplotlib.pyplot as plt
from matplotlib import legend
import pandas as pd
import seaborn as sns
from sklearn.datasets import load_boston, load_iris
import numpy as np

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# Import sample data sets
b = load_boston()
boston = pd.DataFrame(data=b.data, columns=b.feature_names)
temp = pd.Series(data=b.target, name="PRICE")
boston = pd.concat([boston, temp], axis=1)
del temp, b

i = load_iris()
iris = pd.DataFrame(data=i.data, columns=i.feature_names)
temp = pd.Series(data=i.target, name="flower")
iris = pd.concat([iris, temp], axis=1)
iris['flower_id'] = iris['flower']
iris.replace({'flower':{0: 'setosa', 1: 'versicolor', 2: 'virginica'}}, inplace=True)
del temp, i

flights = sns.load_dataset('flights')

# %%
# The `inline` code allows images to show up within your Notebook, rather than a popup window
# %matplotlib inline

# %%
fig = plt.figure()
a = fig.add_subplot()
a = plt.hist(boston['PRICE'])

# %%
fig = plt.figure()
a = fig.add_subplot(2,1,1)
a = plt.hist(boston['PRICE'], bins = 5)
b = fig.add_subplot(2,1,2)
b = plt.hist(boston['PRICE'], bins = 50)

# %%
fig = plt.figure()
a = fig.add_subplot(1,1,1)
a= plt.hist(boston['PRICE'], bins=[0,2,4,8,16,32,64]) # An array sets the edges, not the

# %%
fig = plt.figure()
a = fig.add_subplot()
a = plt.hist(boston['PRICE'], cumulative=True)

# %%
fig = plt.figure()
a = fig.add_subplot()
a = plt.hist(boston['PRICE'], orientation='horizontal')

# %%
fig = plt.figure()
a = fig.add_subplot()
a = plt.hist(iris['sepal length (cm)'])
b = fig.add_subplot()
b = plt.hist(iris['sepal width (cm)'])

# %%
iris_sub = []

fig = plt.figure()

for f in iris['flower'].unique():
    temp = iris[iris['flower'] == f].reset_index()
    iris_sub.append(temp)

for i in iris_sub:
    a = plt.hist(i['sepal length (cm)'])

# %%
iris_sub = []

fig = plt.figure()

for f in iris['flower'].unique():
    temp = iris[iris['flower'] == f].reset_index()
    iris_sub.append(temp)

for i in iris_sub:
    a = plt.hist(i['sepal length (cm)'], 
                 bins=np.arange(4,8.5,0.25))

# %%
iris_sub = []

fig = plt.figure()

for f in iris['flower'].unique():
    temp = iris[iris['flower'] == f].reset_index()
    iris_sub.append(temp)

for i in iris_sub:
    a = plt.hist(i['sepal length (cm)'], 
                 bins=np.arange(4,8.5,0.25), 
                 alpha=0.5)

# %%
iris_sub = []

fig = plt.figure()

for f in iris['flower'].unique():
    temp = iris[iris['flower'] == f].reset_index()
    iris_sub.append(temp)

for i in iris_sub:
    a = plt.hist(i['sepal length (cm)'], 
                 bins=np.arange(4,8.5,0.25), 
                 alpha=0.5)

plt.legend(iris['flower'].unique())

# %%
# Box Plots
print(boston.head())
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  PRICE
# 0     15.3  396.90   4.98   24.0
# 1     17.8  396.90   9.14   21.6
# 2     17.8  392.83   4.03   34.7
# 3     18.7  394.63   2.94   33.4
# 4     18.7  396.90   5.33   36.2

# %%
fig = plt.figure()
a = plt.boxplot(boston['PRICE'])

# %% [markdown]
# Make a box and whisker plot for each column of x or each vector in sequence x. The box extends from the lower to upper quartile values of the data, with a line at the median. The whiskers extend from the box to show the range of the data. Flier points are those past the end of the whiskers.

# %%
fig = plt.figure()
a = plt.boxplot(boston['PRICE'], meanline=True)

# %%
iris_sub = []

fig = plt.figure()

for f in iris['flower'].unique():
    temp = iris[iris['flower'] == f].reset_index()
    iris_sub.append(temp)

for i in iris_sub:
    a = plt.boxplot(i['sepal length (cm)'])

plt.legend(iris['flower'].unique())

# %%
iris_sub = []

fig = plt.figure()

for f in iris['flower'].unique():
    temp = iris[iris['flower'] == f].reset_index()
    iris_sub.append(temp['sepal length (cm)'].values)

a = plt.boxplot(iris_sub, labels=iris['flower'].unique())
# plt.legend(iris['flower'].unique())

# %% [markdown]
# ## Violin Plots

# %%
fig = plt.figure()
a = plt.violinplot(boston['PRICE'])

# %%
fig = plt.figure()
a = plt.violinplot(boston['PRICE'], vert=False)

# %%
iris_sub = []

fig = plt.figure()

for f in iris['flower'].unique():
    temp = iris[iris['flower'] == f].reset_index()
    iris_sub.append(temp['sepal length (cm)'].values)

a = plt.violinplot(iris_sub)

# %%
iris_sub = []

fig = plt.figure()

for f in iris['flower'].unique():
    temp = iris[iris['flower'] == f].reset_index()
    iris_sub.append(temp['sepal length (cm)'].values)

ax = plt.subplot(1,1,1)

a = plt.violinplot(iris_sub)
ax.set_xticks([1,2,3])
ax.set_xticklabels(['A','B','C'])

# %% [markdown]
# ***
# ## Bar Charts

# %%
tips['tip_perc'] = tips['tip'] / tips['total_bill']
tips_g = tips[['day', 'time', 'tip_perc']]

tips_g = tips_g.groupby(by=['day', 'time']).mean()
tips_g = tips_g.fillna(0)
tips_g
# Out:
#              tip_perc
# day  time
# Thur Lunch   0.161301
#      Dinner  0.159744
# Fri  Lunch   0.188765
#      Dinner  0.158916
# Sat  Lunch   0.000000
#      Dinner  0.153152
# Sun  Lunch   0.000000
#      Dinner  0.166897

# %%
a = plt.bar(3, tips_g['tip_perc'].mean())

# %%
categories = []
for i in range(len(tips_g.index)):
    categories.append(' '.join(tips_g.index[i]))
# Out:
# ['Thur Lunch',
#  'Thur Dinner',
#  'Fri Lunch',
#  'Fri Dinner',
#  'Sat Lunch',
#  'Sat Dinner',
#  'Sun Lunch',
#  'Sun Dinner']

# %%
a = plt.bar(np.arange(len(categories)), tips_g['tip_perc'])

# %%
a = plt.bar(np.arange(len(categories)), tips_g['tip_perc'])
plt.xticks(np.arange(len(categories)), categories)
# Out:
# ([<matplotlib.axis.XTick at 0x10a00d5f8>,
# ...
#  <a list of 8 Text xticklabel objects>)

# %%
a = plt.barh(np.arange(len(categories)), tips_g['tip_perc'])
plt.yticks(np.arange(len(categories)), categories)
# Out:
# ([<matplotlib.axis.YTick at 0x10ab09c50>,
# ...
#  <a list of 8 Text yticklabel objects>)
